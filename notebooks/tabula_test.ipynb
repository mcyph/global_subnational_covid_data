# %%
import tabula
df2 = tabula.read_pdf("https://www.parliament.tas.gov.au/ha/halists.pdf", pages=(1, 2, 3, 4))
df2
# Out:
# Got stderr: Oct. 26, 2020 1:51:07 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Oct. 26, 2020 1:51:08 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Oct. 26, 2020 1:51:08 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TimesNewRomanPS-BoldItalicMT'
# Oct. 26, 2020 1:51:08 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TimesNewRomanPS-BoldMT'
# Oct. 26, 2020 1:51:08 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPS-ItalicMT'
# Oct. 26, 2020 1:51:09 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# ...
